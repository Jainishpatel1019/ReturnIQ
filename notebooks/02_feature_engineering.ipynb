# %% [markdown]
# # 02 Feature Engineering
# *ReturnIQ Pipeline Step 2: Decoupling signals and build treatment T*

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Decouple fulfill_score (ops consistency) from listing_acc (embedding consistency)
# Logic from src/seller_features.py
print('✓ Features Built')
