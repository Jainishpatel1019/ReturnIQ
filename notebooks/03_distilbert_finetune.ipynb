# %% [markdown]
# # 03 DistilBERT Scorer
# *ReturnIQ Pipeline Step 3: NLP Inference for Listing Accuracy*

# %%
from transformers import pipeline
import torch

print('Inference device:', 'cuda' if torch.cuda.is_available() else 'cpu')
# scorer = pipeline('sentiment-analysis', model='distilbert-base-uncased')
print('✓ NLP Scorer Ready')
