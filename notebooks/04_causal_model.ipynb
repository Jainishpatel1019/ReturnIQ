# %% [markdown]
# # 04 Causal Model
# *ReturnIQ Pipeline Step 4: CausalForestDML Estimation*

# %%
from econml.dml import CausalForestDML
from xgboost import XGBRegressor
import joblib

print('Running 200-iteration bootstrap for 95% CI...')
# Logic from src/causal_model.py
print('✓ Model Serialized to models/causal_forest.pkl')
